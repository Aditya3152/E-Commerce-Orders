# %%
import pandas as pd

# Load raw data
raw_path = "../data/raw/orders.csv"
df_raw = pd.read_csv(raw_path)

# Quick check
print("Raw shape:", df_raw.shape)
df_raw.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 # Load raw data
#       4 raw_path = "../data/raw/orders.csv"
# ----> 5 df_raw = pd.read_csv(raw_path)
#       7 # Quick check
#       8 print("Raw shape:", df_raw.shape)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/apple/E-Commerce-Orders/notebooks'

# %%
os.listdir("../data/raw")
# Out:
# []

# %%
import os
os.getcwd()
# Out:
# '/Users/apple/E-Commerce-Orders/notebooks'

# %%
# Load raw data
raw_path = "../data/raw/orders.csv"
df_raw = pd.read_csv(raw_path)

# Quick check
print("Raw shape:", df_raw.shape)
df_raw.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Load raw data
#       2 raw_path = "../data/raw/orders.csv"
# ----> 3 df_raw = pd.read_csv(raw_path)
#       5 # Quick check
#       6 print("Raw shape:", df_raw.shape)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
# Load raw data
raw_path = "../data/raw/orders.csv"
df_raw = pd.read_csv(raw_path)

# Quick check
print("Raw shape:", df_raw.shape)
df_raw.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Load raw data
#       2 raw_path = "../data/raw/orders.csv"
# ----> 3 df_raw = pd.read_csv(raw_path)
#       5 # Quick check
#       6 print("Raw shape:", df_raw.shape)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
# Load raw data
raw_path = "../data/raw/data.csv"
df_raw = pd.read_csv(raw_path)

# Quick check
print("Raw shape:", df_raw.shape)
df_raw.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Load raw data
#       2 raw_path = "../data/raw/data.csv"
# ----> 3 df_raw = pd.read_csv(raw_path)
#       5 # Quick check
#       6 print("Raw shape:", df_raw.shape)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
# Load raw data
raw_path = "../data/raw/data.csv"
df_raw = pd.read_csv(raw_path, encoding='ISO-8859-1')

# Quick check
print("Raw shape:", df_raw.shape)
df_raw.head()
# Out:
# Raw shape: (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# Drop duplicate rows
df_clean = df_raw.drop_duplicates()

# Remove extra spaces in column names
df_clean.columns = df_clean.columns.str.strip()

# Fill missing values (adjust columns as needed)
df_clean = df_clean.fillna({
    'customer_name': 'Unknown',
    'city': 'Unknown',
    'amount': 0
})

print("Cleaned shape:", df_clean.shape)
df_clean.head()
# Out:
# Cleaned shape: (536641, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# Ensure folders exist
os.makedirs("../data/processed", exist_ok=True)

# Save files
df_raw.to_csv("../data/raw/orders_snapshot.csv", index=False)
df_clean.to_csv(processed_path, index=False)

print("✅ Saved snapshots:")
print("- Raw snapshot: ../data/raw/orders_snapshot.csv")
print("- Cleaned data: ../data/processed/orders_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       4 # Save files
#       5 df_raw.to_csv("../data/raw/orders_snapshot.csv", index=False)
# ----> 6 df_clean.to_csv(processed_path, index=False)
#       8 print("✅ Saved snapshots:")
#       9 print("- Raw snapshot: ../data/raw/orders_snapshot.csv")
#
# NameError: name 'processed_path' is not defined

# %%
processed_path = "../data/processed/orders_cleaned.csv"

# %%
raw_path = "../data/raw/orders.csv"

# %%
import os

# Define file paths
raw_path = "../data/raw/orders.csv"
processed_path = "../data/processed/orders_cleaned.csv"

# Make sure the folders exist
os.makedirs("../data/raw", exist_ok=True)
os.makedirs("../data/processed", exist_ok=True)

print("✅ Paths are set:")
print("Raw path:", raw_path)
print("Processed path:", processed_path)
# Out:
# ✅ Paths are set:
# Raw path: ../data/raw/orders.csv
# Processed path: ../data/processed/orders_cleaned.csv

# %%
df_raw.to_csv("../data/raw/orders_snapshot.csv", index=False)
df_clean.to_csv(processed_path, index=False)
